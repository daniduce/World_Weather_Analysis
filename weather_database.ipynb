# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the API key.
from config import g_key

# Import the datetime module from the datetime library.
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6fb30e146ce48978787ba4314537e78c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({
            "City": city.title(),
            "Country": city_country,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Weather Description": city_description,
        })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | polunochnoye
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | raska
# Processing Record 5 of Set 1 | loreto
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | nouadhibou
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | hvammstangi
# City not found. Skipping...
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | port elizabeth
# Processing Record 12 of Set 1 | tigil
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | susuman
# Processing Record 17 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | vao
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | aklavik
# Processing Record 22 of Set 1 | pathein
# Processing Record 23 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | airai
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | grindavik
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | kavieng
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | souillac
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | camacha
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | nantucket
# Processing Record 44 of Set 1 | obihiro
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | araouane
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | port augusta
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | alofi
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 2 | thunder bay
# Processing Record 7 of Set 2 | acari
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | svetlogorsk
# Processing Record 10 of Set 2 | beloha
# Processing Record 11 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | saint-joseph
# Processing Record 14 of Set 2 | cuamba
# Processing Record 15 of Set 2 | zyryanka
# Processing Record 16 of Set 2 | lambarene
# Processing Record 17 of Set 2 | miri
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | iqaluit
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | dingle
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | padang
# Processing Record 25 of Set 2 | chokurdakh
# Processing Record 26 of Set 2 | keratea
# Processing Record 27 of Set 2 | beaverton
# Processing Record 28 of Set 2 | nelson bay
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | honiara
# Processing Record 31 of Set 2 | kiunga
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | kjopsvik
# Processing Record 34 of Set 2 | husavik
# Processing Record 35 of Set 2 | danville
# Processing Record 36 of Set 2 | dzilam gonzalez
# Processing Record 37 of Set 2 | renfrew
# Processing Record 38 of Set 2 | debica
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | pozo colorado
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | itaituba
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | pital
# Processing Record 46 of Set 2 | tokur
# Processing Record 47 of Set 2 | hue
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | morden
# Processing Record 1 of Set 3 | bijie
# Processing Record 2 of Set 3 | kununurra
# Processing Record 3 of Set 3 | yasenskaya
# Processing Record 4 of Set 3 | liverpool
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | guerrero negro
# Processing Record 7 of Set 3 | rio grande
# Processing Record 8 of Set 3 | shieli
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | roebourne
# Processing Record 11 of Set 3 | mangrol
# Processing Record 12 of Set 3 | tabuk
# Processing Record 13 of Set 3 | santa cruz
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | hervey bay
# Processing Record 16 of Set 3 | milledgeville
# Processing Record 17 of Set 3 | sebaco
# Processing Record 18 of Set 3 | emerald
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | dire
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | kamiiso
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | marzuq
# Processing Record 29 of Set 3 | ocampo
# Processing Record 30 of Set 3 | pedasi
# Processing Record 31 of Set 3 | watsa
# Processing Record 32 of Set 3 | tuktoyaktuk
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | kousseri
# Processing Record 35 of Set 3 | westport
# Processing Record 36 of Set 3 | broken hill
# Processing Record 37 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 3 | faya
# Processing Record 39 of Set 3 | san cristobal
# Processing Record 40 of Set 3 | luganville
# Processing Record 41 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 3 | ossora
# Processing Record 43 of Set 3 | yerbogachen
# Processing Record 44 of Set 3 | kirakira
# Processing Record 45 of Set 3 | talas
# Processing Record 46 of Set 3 | praia
# Processing Record 47 of Set 3 | zverinogolovskoye
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | taltal
# Processing Record 50 of Set 3 | mbandaka
# Processing Record 1 of Set 4 | upernavik
# Processing Record 2 of Set 4 | aleksandrov gay
# Processing Record 3 of Set 4 | otradnoye
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | rusera
# Processing Record 6 of Set 4 | jining
# Processing Record 7 of Set 4 | gorontalo
# Processing Record 8 of Set 4 | hamilton
# Processing Record 9 of Set 4 | liezen
# Processing Record 10 of Set 4 | ribeira grande
# Processing Record 11 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | port hardy
# Processing Record 14 of Set 4 | roshni-chu
# Processing Record 15 of Set 4 | tautira
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | ilulissat
# Processing Record 18 of Set 4 | benguela
# Processing Record 19 of Set 4 | melilla
# Processing Record 20 of Set 4 | bonthe
# Processing Record 21 of Set 4 | williamsport
# Processing Record 22 of Set 4 | svetlaya
# Processing Record 23 of Set 4 | raudeberg
# Processing Record 24 of Set 4 | asfi
# Processing Record 25 of Set 4 | akdepe
# Processing Record 26 of Set 4 | taoudenni
# Processing Record 27 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 4 | hermanus
# Processing Record 29 of Set 4 | pangai
# Processing Record 30 of Set 4 | georgetown
# Processing Record 31 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 32 of Set 4 | guajara-mirim
# City not found. Skipping...
# Processing Record 33 of Set 4 | mabiton
# Processing Record 34 of Set 4 | chuy
# Processing Record 35 of Set 4 | riviere-au-renard
# Processing Record 36 of Set 4 | greymouth
# Processing Record 37 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | bandarbeyla
# Processing Record 39 of Set 4 | kirovskiy
# Processing Record 40 of Set 4 | comodoro rivadavia
# Processing Record 41 of Set 4 | monduli
# Processing Record 42 of Set 4 | ullapool
# Processing Record 43 of Set 4 | skegness
# Processing Record 44 of Set 4 | nome
# Processing Record 45 of Set 4 | kenai
# Processing Record 46 of Set 4 | makinsk
# Processing Record 47 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 4 | tura
# Processing Record 49 of Set 4 | ueckermunde
# Processing Record 50 of Set 4 | carbonia
# Processing Record 1 of Set 5 | namibe
# Processing Record 2 of Set 5 | watertown
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | kloulklubed
# Processing Record 5 of Set 5 | riohacha
# Processing Record 6 of Set 5 | fairbanks
# Processing Record 7 of Set 5 | madang
# Processing Record 8 of Set 5 | skibbereen
# Processing Record 9 of Set 5 | zdvinsk
# Processing Record 10 of Set 5 | grajau
# Processing Record 11 of Set 5 | koumac
# Processing Record 12 of Set 5 | dabola
# Processing Record 13 of Set 5 | ayer tawar
# Processing Record 14 of Set 5 | kieta
# Processing Record 15 of Set 5 | lompoc
# Processing Record 16 of Set 5 | kaeo
# Processing Record 17 of Set 5 | shakhtinsk
# Processing Record 18 of Set 5 | petatlan
# Processing Record 19 of Set 5 | moses lake
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 22 of Set 5 | erenhot
# Processing Record 23 of Set 5 | arlit
# Processing Record 24 of Set 5 | mtsensk
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | zhezkazgan
# Processing Record 27 of Set 5 | linxia
# Processing Record 28 of Set 5 | biu
# Processing Record 29 of Set 5 | bahraich
# Processing Record 30 of Set 5 | perote
# Processing Record 31 of Set 5 | waipawa
# Processing Record 32 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 5 | cayenne
# Processing Record 34 of Set 5 | luderitz
# Processing Record 35 of Set 5 | salalah
# Processing Record 36 of Set 5 | passy
# Processing Record 37 of Set 5 | bartica
# Processing Record 38 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 5 | laguna
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | tvoroyri
# Processing Record 42 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 5 | galabovo
# Processing Record 44 of Set 5 | haines junction
# Processing Record 45 of Set 5 | danilovka
# Processing Record 46 of Set 5 | straumen
# Processing Record 47 of Set 5 | burnie
# Processing Record 48 of Set 5 | clyde river
# Processing Record 49 of Set 5 | vila do maio
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | scarborough
# Processing Record 2 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 6 | batagay
# Processing Record 4 of Set 6 | goure
# Processing Record 5 of Set 6 | tasiilaq
# Processing Record 6 of Set 6 | tucuman
# Processing Record 7 of Set 6 | shubarshi
# Processing Record 8 of Set 6 | ola
# Processing Record 9 of Set 6 | khorixas
# Processing Record 10 of Set 6 | morehead
# Processing Record 11 of Set 6 | vilyuysk
# Processing Record 12 of Set 6 | vega de alatorre
# Processing Record 13 of Set 6 | henties bay
# Processing Record 14 of Set 6 | sistranda
# Processing Record 15 of Set 6 | inirida
# Processing Record 16 of Set 6 | vienne
# Processing Record 17 of Set 6 | general cepeda
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | banjarmasin
# Processing Record 20 of Set 6 | kupang
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | dicabisagan
# Processing Record 23 of Set 6 | aswan
# Processing Record 24 of Set 6 | harper
# Processing Record 25 of Set 6 | maua
# Processing Record 26 of Set 6 | aldan
# Processing Record 27 of Set 6 | kaitangata
# Processing Record 28 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | sal rei
# Processing Record 30 of Set 6 | alta floresta
# Processing Record 31 of Set 6 | san patricio
# Processing Record 32 of Set 6 | harnai
# Processing Record 33 of Set 6 | horsham
# Processing Record 34 of Set 6 | christchurch
# Processing Record 35 of Set 6 | celestun
# Processing Record 36 of Set 6 | lazaro cardenas
# Processing Record 37 of Set 6 | progreso
# Processing Record 38 of Set 6 | zalantun
# Processing Record 39 of Set 6 | shelburne
# Processing Record 40 of Set 6 | bilibino
# Processing Record 41 of Set 6 | marawi
# Processing Record 42 of Set 6 | benjamin constant
# Processing Record 43 of Set 6 | maniitsoq
# Processing Record 44 of Set 6 | nizhnevartovsk
# Processing Record 45 of Set 6 | neiafu
# Processing Record 46 of Set 6 | xining
# Processing Record 47 of Set 6 | santiago del estero
# Processing Record 48 of Set 6 | gravdal
# Processing Record 49 of Set 6 | narayanpet
# Processing Record 50 of Set 6 | ferme-neuve
# Processing Record 1 of Set 7 | igarka
# Processing Record 2 of Set 7 | paris
# Processing Record 3 of Set 7 | west bay
# Processing Record 4 of Set 7 | riyadh
# Processing Record 5 of Set 7 | victoria
# Processing Record 6 of Set 7 | bantry
# Processing Record 7 of Set 7 | lagoa
# Processing Record 8 of Set 7 | cherskiy
# Processing Record 9 of Set 7 | san policarpo
# Processing Record 10 of Set 7 | craig
# Processing Record 11 of Set 7 | gorin
# Processing Record 12 of Set 7 | bayshore gardens
# Processing Record 13 of Set 7 | cozumel
# Processing Record 14 of Set 7 | richards bay
# Processing Record 15 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 7 | torbay
# Processing Record 17 of Set 7 | thinadhoo
# Processing Record 18 of Set 7 | north bend
# Processing Record 19 of Set 7 | shira
# Processing Record 20 of Set 7 | coahuayana
# Processing Record 21 of Set 7 | biak
# Processing Record 22 of Set 7 | rosetta
# Processing Record 23 of Set 7 | praia da vitoria
# Processing Record 24 of Set 7 | khasan
# Processing Record 25 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 26 of Set 7 | maxixe
# Processing Record 27 of Set 7 | mikhaylovka
# Processing Record 28 of Set 7 | mokhsogollokh
# Processing Record 29 of Set 7 | pacific grove
# Processing Record 30 of Set 7 | lasa
# Processing Record 31 of Set 7 | avera
# Processing Record 32 of Set 7 | muzaffarpur
# Processing Record 33 of Set 7 | nisia floresta
# Processing Record 34 of Set 7 | okandja
# City not found. Skipping...
# Processing Record 35 of Set 7 | bengkulu
# Processing Record 36 of Set 7 | malanville
# Processing Record 37 of Set 7 | bafoulabe
# Processing Record 38 of Set 7 | kruisfontein
# Processing Record 39 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 40 of Set 7 | taree
# Processing Record 41 of Set 7 | vaitape
# Processing Record 42 of Set 7 | touros
# Processing Record 43 of Set 7 | karaton
# Processing Record 44 of Set 7 | high level
# Processing Record 45 of Set 7 | marystown
# Processing Record 46 of Set 7 | menongue
# Processing Record 47 of Set 7 | kemijarvi
# Processing Record 48 of Set 7 | los llanos de aridane
# Processing Record 49 of Set 7 | kalmunai
# Processing Record 50 of Set 7 | tuatapere
# Processing Record 1 of Set 8 | aleksandrovskiy zavod
# Processing Record 2 of Set 8 | balabac
# Processing Record 3 of Set 8 | myanaung
# Processing Record 4 of Set 8 | tank
# Processing Record 5 of Set 8 | gombong
# Processing Record 6 of Set 8 | roma
# Processing Record 7 of Set 8 | amravati
# Processing Record 8 of Set 8 | awbari
# Processing Record 9 of Set 8 | fairview
# Processing Record 10 of Set 8 | khabary
# Processing Record 11 of Set 8 | staicele
# Processing Record 12 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 8 | gisborne
# Processing Record 14 of Set 8 | batemans bay
# Processing Record 15 of Set 8 | ljungby
# Processing Record 16 of Set 8 | wyndham
# Processing Record 17 of Set 8 | berdigestyakh
# Processing Record 18 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 8 | moerai
# Processing Record 20 of Set 8 | nabire
# Processing Record 21 of Set 8 | urucara
# Processing Record 22 of Set 8 | oban
# Processing Record 23 of Set 8 | altay
# Processing Record 24 of Set 8 | adre
# Processing Record 25 of Set 8 | muli
# Processing Record 26 of Set 8 | san quintin
# Processing Record 27 of Set 8 | cururupu
# Processing Record 28 of Set 8 | manicore
# Processing Record 29 of Set 8 | sinegorye
# Processing Record 30 of Set 8 | carmelo
# Processing Record 31 of Set 8 | vila velha
# Processing Record 32 of Set 8 | lorengau
# Processing Record 33 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 8 | kaduna
# Processing Record 35 of Set 8 | champua
# Processing Record 36 of Set 8 | nizhniy tsasuchey
# Processing Record 37 of Set 8 | sabattus
# Processing Record 38 of Set 8 | alekseyevka
# Processing Record 39 of Set 8 | harnoli
# Processing Record 40 of Set 8 | zhanaozen
# Processing Record 41 of Set 8 | sumenep
# Processing Record 42 of Set 8 | rio verde de mato grosso
# Processing Record 43 of Set 8 | sorong
# Processing Record 44 of Set 8 | rio tercero
# Processing Record 45 of Set 8 | talara
# Processing Record 46 of Set 8 | kropotkin
# Processing Record 47 of Set 8 | nuuk
# Processing Record 48 of Set 8 | poum
# Processing Record 49 of Set 8 | viedma
# Processing Record 50 of Set 8 | port shepstone
# Processing Record 1 of Set 9 | dunedin
# Processing Record 2 of Set 9 | genoa
# Processing Record 3 of Set 9 | quatre cocos
# Processing Record 4 of Set 9 | asyut
# Processing Record 5 of Set 9 | new richmond
# Processing Record 6 of Set 9 | nemuro
# Processing Record 7 of Set 9 | kholtoson
# Processing Record 8 of Set 9 | yarkovo
# Processing Record 9 of Set 9 | biloela
# Processing Record 10 of Set 9 | inhambane
# Processing Record 11 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 9 | kawhia
# Processing Record 13 of Set 9 | ostrovnoy
# Processing Record 14 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 9 | pouebo
# Processing Record 16 of Set 9 | novaya bryan
# Processing Record 17 of Set 9 | fortuna
# Processing Record 18 of Set 9 | ballina
# Processing Record 19 of Set 9 | hasaki
# Processing Record 20 of Set 9 | maneadero
# Processing Record 21 of Set 9 | mori
# Processing Record 22 of Set 9 | kokopo
# Processing Record 23 of Set 9 | muscle shoals
# Processing Record 24 of Set 9 | todos santos
# Processing Record 25 of Set 9 | mogadouro
# Processing Record 26 of Set 9 | makakilo city
# Processing Record 27 of Set 9 | hofn
# Processing Record 28 of Set 9 | buraydah
# Processing Record 29 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 9 | bucerias
# Processing Record 31 of Set 9 | bejucal
# Processing Record 32 of Set 9 | sao joao da barra
# Processing Record 33 of Set 9 | mazagao
# Processing Record 34 of Set 9 | fallon
# Processing Record 35 of Set 9 | meulaboh
# Processing Record 36 of Set 9 | alexandria
# Processing Record 37 of Set 9 | qujing
# Processing Record 38 of Set 9 | jumla
# Processing Record 39 of Set 9 | kamphaeng phet
# Processing Record 40 of Set 9 | constitucion
# Processing Record 41 of Set 9 | samarai
# Processing Record 42 of Set 9 | vila franca do campo
# Processing Record 43 of Set 9 | chulman
# Processing Record 44 of Set 9 | marsh harbour
# Processing Record 45 of Set 9 | bairiki
# Processing Record 46 of Set 9 | felanitx
# Processing Record 47 of Set 9 | komsomolskiy
# Processing Record 48 of Set 9 | rawson
# Processing Record 49 of Set 9 | lata
# Processing Record 50 of Set 9 | ulladulla
# Processing Record 1 of Set 10 | betanzos
# Processing Record 2 of Set 10 | leland
# Processing Record 3 of Set 10 | ubinskoye
# Processing Record 4 of Set 10 | lafia
# Processing Record 5 of Set 10 | qurbus
# Processing Record 6 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 7 of Set 10 | isangel
# Processing Record 8 of Set 10 | melita
# Processing Record 9 of Set 10 | sur
# Processing Record 10 of Set 10 | manthani
# Processing Record 11 of Set 10 | labuhan
# Processing Record 12 of Set 10 | pauini
# Processing Record 13 of Set 10 | hami
# Processing Record 14 of Set 10 | yulara
# Processing Record 15 of Set 10 | langsa
# Processing Record 16 of Set 10 | guanica
# Processing Record 17 of Set 10 | helena
# Processing Record 18 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 10 | alugan
# Processing Record 20 of Set 10 | bereda
# Processing Record 21 of Set 10 | naze
# Processing Record 22 of Set 10 | kanchanaburi
# Processing Record 23 of Set 10 | havre-saint-pierre
# Processing Record 24 of Set 10 | port hedland
# Processing Record 25 of Set 10 | tiarei
# Processing Record 26 of Set 10 | wanning
# Processing Record 27 of Set 10 | svay rieng
# Processing Record 28 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 10 | muzhi
# Processing Record 30 of Set 10 | road town
# Processing Record 31 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 10 | azanka
# Processing Record 33 of Set 10 | guarapari
# Processing Record 34 of Set 10 | talavera de la reina
# Processing Record 35 of Set 10 | tevaitoa
# Processing Record 36 of Set 10 | vangaindrano
# Processing Record 37 of Set 10 | ahipara
# Processing Record 38 of Set 10 | ambilobe
# Processing Record 39 of Set 10 | khomutovka
# Processing Record 40 of Set 10 | dong hoi
# Processing Record 41 of Set 10 | santa cruz de la palma
# Processing Record 42 of Set 10 | pisco
# Processing Record 43 of Set 10 | daru
# Processing Record 44 of Set 10 | yatou
# Processing Record 45 of Set 10 | tilichiki
# Processing Record 46 of Set 10 | sioux lookout
# Processing Record 47 of Set 10 | kolpashevo
# Processing Record 48 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 49 of Set 10 | jalu
# Processing Record 50 of Set 10 | porto murtinho
# Processing Record 1 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 2 of Set 11 | yurimaguas
# Processing Record 3 of Set 11 | magadan
# Processing Record 4 of Set 11 | veraval
# Processing Record 5 of Set 11 | saint-augustin
# Processing Record 6 of Set 11 | seoul
# Processing Record 7 of Set 11 | port lincoln
# Processing Record 8 of Set 11 | kendari
# Processing Record 9 of Set 11 | zeya
# Processing Record 10 of Set 11 | maldonado
# Processing Record 11 of Set 11 | carnaiba
# Processing Record 12 of Set 11 | kamenka
# Processing Record 13 of Set 11 | kudahuvadhoo
# Processing Record 14 of Set 11 | chingirlau
# Processing Record 15 of Set 11 | mehamn
# Processing Record 16 of Set 11 | norton
# Processing Record 17 of Set 11 | talnakh
# Processing Record 18 of Set 11 | iquitos
# Processing Record 19 of Set 11 | matagami
# Processing Record 20 of Set 11 | chunhuhub
# Processing Record 21 of Set 11 | foumbot
# Processing Record 22 of Set 11 | camana
# Processing Record 23 of Set 11 | grand forks
# Processing Record 24 of Set 11 | la sarre
# Processing Record 25 of Set 11 | awjilah
# Processing Record 26 of Set 11 | malanje
# Processing Record 27 of Set 11 | coquimbo
# Processing Record 28 of Set 11 | deputatskiy
# Processing Record 29 of Set 11 | preobrazheniye
# Processing Record 30 of Set 11 | sohag
# Processing Record 31 of Set 11 | bulgan
# Processing Record 32 of Set 11 | paamiut
# Processing Record 33 of Set 11 | doha
# Processing Record 34 of Set 11 | stokmarknes
# Processing Record 35 of Set 11 | pangnirtung
# Processing Record 36 of Set 11 | suntar
# Processing Record 37 of Set 11 | beringovskiy
# Processing Record 38 of Set 11 | bara
# Processing Record 39 of Set 11 | broome
# Processing Record 40 of Set 11 | zhuhai
# Processing Record 41 of Set 11 | kutum
# Processing Record 42 of Set 11 | saint-pierre
# Processing Record 43 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 11 | vilhena
# Processing Record 45 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 46 of Set 11 | tagusao
# Processing Record 47 of Set 11 | abengourou
# Processing Record 48 of Set 11 | guiberoua
# Processing Record 49 of Set 11 | sandwick
# Processing Record 50 of Set 11 | discovery bay
# Processing Record 1 of Set 12 | flin flon
# Processing Record 2 of Set 12 | aniva
# Processing Record 3 of Set 12 | kahului
# Processing Record 4 of Set 12 | neuquen
# Processing Record 5 of Set 12 | maceio
# Processing Record 6 of Set 12 | vyazma
# Processing Record 7 of Set 12 | show low
# Processing Record 8 of Set 12 | ixtapa
# Processing Record 9 of Set 12 | zelenets
# Processing Record 10 of Set 12 | balakovo
# Processing Record 11 of Set 12 | dudinka
# Processing Record 12 of Set 12 | valenza
# Processing Record 13 of Set 12 | gunnedah
# Processing Record 14 of Set 12 | boca do acre
# Processing Record 15 of Set 12 | synya
# Processing Record 16 of Set 12 | kaifeng
# Processing Record 17 of Set 12 | karachi
# Processing Record 18 of Set 12 | gornyy
# Processing Record 19 of Set 12 | great yarmouth
# Processing Record 20 of Set 12 | songjianghe
# Processing Record 21 of Set 12 | ambam
# Processing Record 22 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 23 of Set 12 | ust-tsilma
# Processing Record 24 of Set 12 | nanortalik
# Processing Record 25 of Set 12 | curaca
# Processing Record 26 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 12 | balikpapan
# Processing Record 28 of Set 12 | nkoteng
# Processing Record 29 of Set 12 | dryden
# Processing Record 30 of Set 12 | mahibadhoo
# Processing Record 31 of Set 12 | katsuura
# Processing Record 32 of Set 12 | santiago
# Processing Record 33 of Set 12 | northam
# Processing Record 34 of Set 12 | tabou
# Processing Record 35 of Set 12 | pangody
# Processing Record 36 of Set 12 | xichang
# Processing Record 37 of Set 12 | chulym
# Processing Record 38 of Set 12 | maarianhamina
# Processing Record 39 of Set 12 | baracoa
# Processing Record 40 of Set 12 | janakpur road
# City not found. Skipping...
# Processing Record 41 of Set 12 | itoman
# Processing Record 42 of Set 12 | inuvik
# Processing Record 43 of Set 12 | hirara
# Processing Record 44 of Set 12 | male
# Processing Record 45 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 12 | solnechnyy
# Processing Record 47 of Set 12 | la rioja
# Processing Record 48 of Set 12 | hondo
# Processing Record 49 of Set 12 | wabana
# Processing Record 50 of Set 12 | skara
# Processing Record 1 of Set 13 | martapura
# Processing Record 2 of Set 13 | almaznyy
# Processing Record 3 of Set 13 | ucluelet
# Processing Record 4 of Set 13 | verkhnyaya inta
# Processing Record 5 of Set 13 | rodrigues alves
# Processing Record 6 of Set 13 | vasilsursk
# Processing Record 7 of Set 13 | viloco
# Processing Record 8 of Set 13 | homer
# Processing Record 9 of Set 13 | bukama
# Processing Record 10 of Set 13 | sabang
# Processing Record 11 of Set 13 | miles city
# Processing Record 12 of Set 13 | saint anthony
# Processing Record 13 of Set 13 | lincoln
# Processing Record 14 of Set 13 | kidal
# Processing Record 15 of Set 13 | kochi
# Processing Record 16 of Set 13 | villazon
# Processing Record 17 of Set 13 | gat
# Processing Record 18 of Set 13 | chapais
# Processing Record 19 of Set 13 | cabra
# Processing Record 20 of Set 13 | vardo
# Processing Record 21 of Set 13 | jiaozhou
# Processing Record 22 of Set 13 | xocali
# Processing Record 23 of Set 13 | hamina
# Processing Record 24 of Set 13 | alghero
# Processing Record 25 of Set 13 | sola
# Processing Record 26 of Set 13 | tual
# Processing Record 27 of Set 13 | imbituba
# Processing Record 28 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 29 of Set 13 | burns lake
# Processing Record 30 of Set 13 | kavos
# Processing Record 31 of Set 13 | barra da estiva
# Processing Record 32 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 13 | dharchula
# Processing Record 34 of Set 13 | prado
# Processing Record 35 of Set 13 | malkangiri
# Processing Record 36 of Set 13 | catungan
# Processing Record 37 of Set 13 | bolshaya vishera
# City not found. Skipping...
# Processing Record 38 of Set 13 | portland
# Processing Record 39 of Set 13 | calderitas
# Processing Record 40 of Set 13 | tomatlan
# Processing Record 41 of Set 13 | vysokogornyy
# Processing Record 42 of Set 13 | eyl
# Processing Record 43 of Set 13 | ailigandi
# Processing Record 44 of Set 13 | okhotsk
# Processing Record 45 of Set 13 | qinzhou
# Processing Record 46 of Set 13 | parrsboro
# Processing Record 47 of Set 13 | taksimo
# Processing Record 48 of Set 13 | gualeguay
# Processing Record 49 of Set 13 | valleyview
# Processing Record 50 of Set 13 | kaohsiung
# Processing Record 1 of Set 14 | bathsheba
# Processing Record 2 of Set 14 | sao felix do xingu
# Processing Record 3 of Set 14 | hirna
# Processing Record 4 of Set 14 | yar-sale
# Processing Record 5 of Set 14 | rio gallegos
# Processing Record 6 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 14 | damietta
# Processing Record 8 of Set 14 | velyka lepetykha
# Processing Record 9 of Set 14 | urozhayne
# City not found. Skipping...
# Processing Record 10 of Set 14 | chebsara
# Processing Record 11 of Set 14 | brae
# Processing Record 12 of Set 14 | shkotovo-22
# City not found. Skipping...
# Processing Record 13 of Set 14 | serebryansk
# Processing Record 14 of Set 14 | bekasi
# Processing Record 15 of Set 14 | prince george
# Processing Record 16 of Set 14 | hokitika
# Processing Record 17 of Set 14 | lusambo
# Processing Record 18 of Set 14 | brokopondo
# Processing Record 19 of Set 14 | agnibilekrou
# Processing Record 20 of Set 14 | ayan
# Processing Record 21 of Set 14 | raichur
# Processing Record 22 of Set 14 | meadow lake
# Processing Record 23 of Set 14 | xinan
# Processing Record 24 of Set 14 | rochester
# Processing Record 25 of Set 14 | la union
# Processing Record 26 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 14 | yumen
# Processing Record 28 of Set 14 | namatanai
# Processing Record 29 of Set 14 | apricena
# Processing Record 30 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 14 | banda aceh
# Processing Record 33 of Set 14 | asau
# Processing Record 34 of Set 14 | saint-georges
# Processing Record 35 of Set 14 | myingyan
# Processing Record 36 of Set 14 | antalaha
# Processing Record 37 of Set 14 | yining
# Processing Record 38 of Set 14 | cockburn town
# Processing Record 39 of Set 14 | pangoa
# Processing Record 40 of Set 14 | manta
# Processing Record 41 of Set 14 | ha tinh
# Processing Record 42 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 14 | perustica
# City not found. Skipping...
# Processing Record 44 of Set 14 | santiago de cao
# Processing Record 45 of Set 14 | tshikapa
# Processing Record 46 of Set 14 | atok
# Processing Record 47 of Set 14 | chernyshevskiy
# Processing Record 48 of Set 14 | darhan
# Processing Record 49 of Set 14 | calvia
# Processing Record 50 of Set 14 | puerto baquerizo moreno
# Processing Record 1 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 15 | nurota
# Processing Record 3 of Set 15 | viytivka
# Processing Record 4 of Set 15 | karratha
# Processing Record 5 of Set 15 | college
# Processing Record 6 of Set 15 | ustrzyki dolne
# Processing Record 7 of Set 15 | lugovoy
# Processing Record 8 of Set 15 | zhigansk
# Processing Record 9 of Set 15 | plettenberg bay
# Processing Record 10 of Set 15 | belousovka
# Processing Record 11 of Set 15 | kedrovyy
# Processing Record 12 of Set 15 | lisakovsk
# Processing Record 13 of Set 15 | klaksvik
# Processing Record 14 of Set 15 | bondo
# Processing Record 15 of Set 15 | chara
# Processing Record 16 of Set 15 | carleton place
# Processing Record 17 of Set 15 | kindu
# Processing Record 18 of Set 15 | nogliki
# Processing Record 19 of Set 15 | ambon
# Processing Record 20 of Set 15 | bowen
# Processing Record 21 of Set 15 | tortoli
# Processing Record 22 of Set 15 | ereymentau
# Processing Record 23 of Set 15 | wielun
# Processing Record 24 of Set 15 | mayumba
# Processing Record 25 of Set 15 | kerema
# Processing Record 26 of Set 15 | amherst
# Processing Record 27 of Set 15 | fort nelson
# Processing Record 28 of Set 15 | aragarcas
# Processing Record 29 of Set 15 | sept-iles
# Processing Record 30 of Set 15 | mozarlandia
# Processing Record 31 of Set 15 | vanavara
# Processing Record 32 of Set 15 | coronel martinez
# Processing Record 33 of Set 15 | sobolevo
# Processing Record 34 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 35 of Set 15 | rumuruti
# Processing Record 36 of Set 15 | minsk
# Processing Record 37 of Set 15 | ban nahin
# Processing Record 38 of Set 15 | basco
# Processing Record 39 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 15 | khorinsk
# Processing Record 41 of Set 15 | joshimath
# Processing Record 42 of Set 15 | kissidougou
# Processing Record 43 of Set 15 | colares
# Processing Record 44 of Set 15 | oriximina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Bluff      NZ -46.60  168.33     55.00        96         100
# 1    Polunochnoye      RU  60.87   60.42     32.99        94          30
# 2        Saldanha      ZA -33.01   17.94     68.00        40           0
# 3           Raska      RS  43.29   20.62     57.20        58          75
# 4          Loreto      MX  22.27 -101.97     50.65        80           1
# 5         Ushuaia      AR -54.80  -68.30     50.00        61          75
# 6      Nouadhibou      MR  20.93  -17.03     77.00        61           0
# 7     Yellowknife      CA  62.46 -114.35     18.00        96         100
# 8         Rikitea      PF -23.12 -134.97     74.97        71          64
# 9  Port Elizabeth      ZA -33.92   25.57     64.40        52           0
#
#    Wind Speed Weather Description
# 0        5.01          light rain
# 1        5.75    scattered clouds
# 2       21.92           clear sky
# 3        5.82       broken clouds
# 4        4.88           clear sky
# 5       29.97       broken clouds
# 6       16.11           clear sky
# 7        8.41     overcast clouds
# 8        5.79       broken clouds
# 9       11.41           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
