# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the API key.
from config import g_key

# Import the datetime module from the datetime library.
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6fb30e146ce48978787ba4314537e78c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({
            "City": city.title(),
            "Country": city_country,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Weather Description": city_description,
        })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | yulara
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | tuatapere
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | okhotsk
# Processing Record 8 of Set 1 | lorengau
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | kambove
# Processing Record 11 of Set 1 | fredericton
# Processing Record 12 of Set 1 | laibin
# Processing Record 13 of Set 1 | sambava
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | koraput
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | nouadhibou
# Processing Record 27 of Set 1 | aykhal
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | thaton
# Processing Record 33 of Set 1 | laguna
# Processing Record 34 of Set 1 | berdigestyakh
# Processing Record 35 of Set 1 | victoria
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | santander
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | toora-khem
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | bolshoy lug
# Processing Record 46 of Set 1 | zhucheng
# Processing Record 47 of Set 1 | chapais
# Processing Record 48 of Set 1 | lavrentiya
# Processing Record 49 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 1 | port hardy
# Processing Record 1 of Set 2 | guerrero negro
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | huarmey
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | russell
# Processing Record 6 of Set 2 | mandan
# Processing Record 7 of Set 2 | ocean springs
# Processing Record 8 of Set 2 | bethanien
# Processing Record 9 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | saldanha
# Processing Record 11 of Set 2 | nhamunda
# Processing Record 12 of Set 2 | mareeba
# Processing Record 13 of Set 2 | enshi
# Processing Record 14 of Set 2 | airai
# Processing Record 15 of Set 2 | manzhouli
# Processing Record 16 of Set 2 | belyy yar
# Processing Record 17 of Set 2 | hobyo
# Processing Record 18 of Set 2 | sao filipe
# Processing Record 19 of Set 2 | tura
# Processing Record 20 of Set 2 | leningradskiy
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | ola
# Processing Record 23 of Set 2 | buta
# Processing Record 24 of Set 2 | faanui
# Processing Record 25 of Set 2 | broken hill
# Processing Record 26 of Set 2 | san patricio
# Processing Record 27 of Set 2 | husavik
# Processing Record 28 of Set 2 | topolobampo
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | inuvik
# Processing Record 31 of Set 2 | bud
# Processing Record 32 of Set 2 | lake city
# Processing Record 33 of Set 2 | sinnamary
# Processing Record 34 of Set 2 | palu
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | madimba
# Processing Record 38 of Set 2 | narsaq
# Processing Record 39 of Set 2 | salalah
# Processing Record 40 of Set 2 | rio gallegos
# Processing Record 41 of Set 2 | cockburn town
# Processing Record 42 of Set 2 | moose factory
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | verkhnyaya inta
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | bengkulu
# Processing Record 50 of Set 2 | mirnyy
# Processing Record 1 of Set 3 | atambua
# Processing Record 2 of Set 3 | kitimat
# Processing Record 3 of Set 3 | santa marta
# Processing Record 4 of Set 3 | coquimbo
# Processing Record 5 of Set 3 | meybod
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | shenjiamen
# Processing Record 8 of Set 3 | vila velha
# Processing Record 9 of Set 3 | lasa
# Processing Record 10 of Set 3 | rondonopolis
# Processing Record 11 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 3 | sao joao da barra
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 | winnemucca
# Processing Record 15 of Set 3 | beringovskiy
# Processing Record 16 of Set 3 | ye
# City not found. Skipping...
# Processing Record 17 of Set 3 | roald
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | poum
# Processing Record 20 of Set 3 | quatre cocos
# Processing Record 21 of Set 3 | araouane
# Processing Record 22 of Set 3 | cap malheureux
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | shahrud
# Processing Record 25 of Set 3 | esperance
# Processing Record 26 of Set 3 | sur
# Processing Record 27 of Set 3 | constitucion
# Processing Record 28 of Set 3 | rawson
# Processing Record 29 of Set 3 | atlantic city
# Processing Record 30 of Set 3 | gidam
# Processing Record 31 of Set 3 | bridlington
# Processing Record 32 of Set 3 | erdemli
# Processing Record 33 of Set 3 | bredasdorp
# Processing Record 34 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | turukhansk
# Processing Record 37 of Set 3 | westpunt
# City not found. Skipping...
# Processing Record 38 of Set 3 | abu dhabi
# Processing Record 39 of Set 3 | aksu
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | algiers
# Processing Record 42 of Set 3 | makakilo city
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | sangar
# Processing Record 45 of Set 3 | anadyr
# Processing Record 46 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 3 | isabela
# Processing Record 48 of Set 3 | moyale
# Processing Record 49 of Set 3 | carnarvon
# Processing Record 50 of Set 3 | mount gambier
# Processing Record 1 of Set 4 | plettenberg bay
# Processing Record 2 of Set 4 | kisangani
# Processing Record 3 of Set 4 | oistins
# Processing Record 4 of Set 4 | alice springs
# Processing Record 5 of Set 4 | mikhaylovskoye
# Processing Record 6 of Set 4 | southbridge
# Processing Record 7 of Set 4 | hermanus
# Processing Record 8 of Set 4 | kameno
# Processing Record 9 of Set 4 | northam
# Processing Record 10 of Set 4 | bambous virieux
# Processing Record 11 of Set 4 | kangaatsiaq
# Processing Record 12 of Set 4 | berlevag
# Processing Record 13 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 4 | nikolskoye
# Processing Record 15 of Set 4 | deputatskiy
# Processing Record 16 of Set 4 | chaplynka
# Processing Record 17 of Set 4 | ewa beach
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | komsomolskiy
# Processing Record 20 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 4 | lewistown
# Processing Record 22 of Set 4 | broome
# Processing Record 23 of Set 4 | havre-saint-pierre
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | mildura
# Processing Record 26 of Set 4 | nacala
# Processing Record 27 of Set 4 | lakeville
# Processing Record 28 of Set 4 | caravelas
# Processing Record 29 of Set 4 | toamasina
# Processing Record 30 of Set 4 | sunland park
# Processing Record 31 of Set 4 | tautira
# Processing Record 32 of Set 4 | shimoda
# Processing Record 33 of Set 4 | pietersburg
# Processing Record 34 of Set 4 | karoi
# Processing Record 35 of Set 4 | te anau
# Processing Record 36 of Set 4 | nalut
# Processing Record 37 of Set 4 | valdivia
# Processing Record 38 of Set 4 | trindade
# Processing Record 39 of Set 4 | huadian
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | kruisfontein
# Processing Record 42 of Set 4 | salinopolis
# Processing Record 43 of Set 4 | tanout
# Processing Record 44 of Set 4 | luanda
# Processing Record 45 of Set 4 | mount isa
# Processing Record 46 of Set 4 | gladstone
# Processing Record 47 of Set 4 | la asuncion
# Processing Record 48 of Set 4 | vestmannaeyjar
# Processing Record 49 of Set 4 | okha
# Processing Record 50 of Set 4 | ostrovnoy
# Processing Record 1 of Set 5 | mahebourg
# Processing Record 2 of Set 5 | vanavara
# Processing Record 3 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 5 | port elizabeth
# Processing Record 5 of Set 5 | sorland
# Processing Record 6 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | wajima
# Processing Record 9 of Set 5 | saint-ambroise
# Processing Record 10 of Set 5 | lagoa
# Processing Record 11 of Set 5 | saint-augustin
# Processing Record 12 of Set 5 | bom jesus
# Processing Record 13 of Set 5 | mucurapo
# Processing Record 14 of Set 5 | benguela
# Processing Record 15 of Set 5 | klaksvik
# Processing Record 16 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 5 | bukama
# Processing Record 18 of Set 5 | benghazi
# Processing Record 19 of Set 5 | camacha
# Processing Record 20 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 5 | kathmandu
# Processing Record 22 of Set 5 | taoudenni
# Processing Record 23 of Set 5 | carupano
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | naze
# Processing Record 26 of Set 5 | baraboo
# Processing Record 27 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 5 | luderitz
# Processing Record 29 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 30 of Set 5 | denpasar
# Processing Record 31 of Set 5 | balingasay
# Processing Record 32 of Set 5 | khorixas
# Processing Record 33 of Set 5 | itoman
# Processing Record 34 of Set 5 | bandarbeyla
# Processing Record 35 of Set 5 | kachikau
# City not found. Skipping...
# Processing Record 36 of Set 5 | staryy nadym
# Processing Record 37 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 38 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 5 | dakar
# Processing Record 40 of Set 5 | pierre
# Processing Record 41 of Set 5 | clyde river
# Processing Record 42 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 5 | shitanjing
# Processing Record 44 of Set 5 | watsa
# Processing Record 45 of Set 5 | gobabis
# Processing Record 46 of Set 5 | paraiso
# Processing Record 47 of Set 5 | bohuslav
# Processing Record 48 of Set 5 | port keats
# Processing Record 49 of Set 5 | pisco
# Processing Record 50 of Set 5 | rathdrum
# Processing Record 1 of Set 6 | bilma
# Processing Record 2 of Set 6 | warwick
# Processing Record 3 of Set 6 | ponta do sol
# Processing Record 4 of Set 6 | pokhara
# Processing Record 5 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 6 | galle
# Processing Record 7 of Set 6 | valparaiso
# Processing Record 8 of Set 6 | sabha
# Processing Record 9 of Set 6 | kloulklubed
# Processing Record 10 of Set 6 | ilulissat
# Processing Record 11 of Set 6 | aberlour
# City not found. Skipping...
# Processing Record 12 of Set 6 | buala
# Processing Record 13 of Set 6 | viedma
# Processing Record 14 of Set 6 | kutum
# Processing Record 15 of Set 6 | pemba
# Processing Record 16 of Set 6 | korcula
# Processing Record 17 of Set 6 | nome
# Processing Record 18 of Set 6 | neuquen
# Processing Record 19 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 20 of Set 6 | atakpame
# Processing Record 21 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 6 | dingle
# Processing Record 23 of Set 6 | zhigansk
# Processing Record 24 of Set 6 | garowe
# Processing Record 25 of Set 6 | nivala
# Processing Record 26 of Set 6 | east london
# Processing Record 27 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 6 | pascagoula
# Processing Record 29 of Set 6 | sovetskaya
# Processing Record 30 of Set 6 | hasaki
# Processing Record 31 of Set 6 | himora
# City not found. Skipping...
# Processing Record 32 of Set 6 | talnakh
# Processing Record 33 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 6 | road town
# Processing Record 35 of Set 6 | mahaicony
# City not found. Skipping...
# Processing Record 36 of Set 6 | sao jose da coroa grande
# Processing Record 37 of Set 6 | zainsk
# Processing Record 38 of Set 6 | makokou
# Processing Record 39 of Set 6 | el fuerte
# Processing Record 40 of Set 6 | ca mau
# Processing Record 41 of Set 6 | adrar
# Processing Record 42 of Set 6 | saint george
# Processing Record 43 of Set 6 | souillac
# Processing Record 44 of Set 6 | north bend
# Processing Record 45 of Set 6 | kindu
# Processing Record 46 of Set 6 | pacific grove
# Processing Record 47 of Set 6 | turbat
# Processing Record 48 of Set 6 | wanxian
# Processing Record 49 of Set 6 | linjiang
# Processing Record 50 of Set 6 | yellowknife
# Processing Record 1 of Set 7 | oxbow
# Processing Record 2 of Set 7 | gogrial
# Processing Record 3 of Set 7 | gerede
# Processing Record 4 of Set 7 | port blair
# Processing Record 5 of Set 7 | castel san giovanni
# Processing Record 6 of Set 7 | noumea
# Processing Record 7 of Set 7 | turayf
# Processing Record 8 of Set 7 | provideniya
# Processing Record 9 of Set 7 | jamame
# Processing Record 10 of Set 7 | lompoc
# Processing Record 11 of Set 7 | tahoua
# Processing Record 12 of Set 7 | kenai
# Processing Record 13 of Set 7 | havoysund
# Processing Record 14 of Set 7 | katsuura
# Processing Record 15 of Set 7 | haines junction
# Processing Record 16 of Set 7 | samarai
# Processing Record 17 of Set 7 | abu samrah
# Processing Record 18 of Set 7 | kodiak
# Processing Record 19 of Set 7 | la libertad
# Processing Record 20 of Set 7 | siverek
# Processing Record 21 of Set 7 | altay
# Processing Record 22 of Set 7 | mackay
# Processing Record 23 of Set 7 | viloco
# Processing Record 24 of Set 7 | moorhead
# Processing Record 25 of Set 7 | kargasok
# Processing Record 26 of Set 7 | castro
# Processing Record 27 of Set 7 | hamburg
# Processing Record 28 of Set 7 | coihaique
# Processing Record 29 of Set 7 | joshimath
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | jumla
# Processing Record 32 of Set 7 | tasiilaq
# Processing Record 33 of Set 7 | dali
# Processing Record 34 of Set 7 | harboore
# Processing Record 35 of Set 7 | bure
# Processing Record 36 of Set 7 | gaildorf
# Processing Record 37 of Set 7 | kargil
# Processing Record 38 of Set 7 | botou
# Processing Record 39 of Set 7 | chulym
# Processing Record 40 of Set 7 | tigil
# Processing Record 41 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 7 | fangshan
# Processing Record 43 of Set 7 | veinticinco de mayo
# Processing Record 44 of Set 7 | iznoski
# Processing Record 45 of Set 7 | saint-francois
# Processing Record 46 of Set 7 | dudinka
# Processing Record 47 of Set 7 | san quintin
# Processing Record 48 of Set 7 | padilla
# Processing Record 49 of Set 7 | richards bay
# Processing Record 50 of Set 7 | namibe
# Processing Record 1 of Set 8 | charters towers
# Processing Record 2 of Set 8 | isfana
# Processing Record 3 of Set 8 | perth
# Processing Record 4 of Set 8 | avallon
# Processing Record 5 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 8 | egvekinot
# Processing Record 7 of Set 8 | tessalit
# Processing Record 8 of Set 8 | fortuna
# Processing Record 9 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 10 of Set 8 | lisala
# Processing Record 11 of Set 8 | constantine
# Processing Record 12 of Set 8 | aripuana
# Processing Record 13 of Set 8 | raton
# Processing Record 14 of Set 8 | majene
# Processing Record 15 of Set 8 | camopi
# Processing Record 16 of Set 8 | roura
# Processing Record 17 of Set 8 | zhezkazgan
# Processing Record 18 of Set 8 | upata
# Processing Record 19 of Set 8 | moree
# Processing Record 20 of Set 8 | muisne
# Processing Record 21 of Set 8 | sitka
# Processing Record 22 of Set 8 | kaa-khem
# Processing Record 23 of Set 8 | anderson
# Processing Record 24 of Set 8 | disna
# Processing Record 25 of Set 8 | portland
# Processing Record 26 of Set 8 | bognor regis
# Processing Record 27 of Set 8 | tabanan
# Processing Record 28 of Set 8 | cavalcante
# Processing Record 29 of Set 8 | jalu
# Processing Record 30 of Set 8 | saint-philippe
# Processing Record 31 of Set 8 | tilichiki
# Processing Record 32 of Set 8 | bayshore gardens
# Processing Record 33 of Set 8 | cascais
# Processing Record 34 of Set 8 | miyang
# Processing Record 35 of Set 8 | atsiki
# City not found. Skipping...
# Processing Record 36 of Set 8 | vyazma
# Processing Record 37 of Set 8 | ipixuna
# Processing Record 38 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 8 | cueto
# Processing Record 40 of Set 8 | faya
# Processing Record 41 of Set 8 | billings
# Processing Record 42 of Set 8 | umm kaddadah
# Processing Record 43 of Set 8 | balaipungut
# Processing Record 44 of Set 8 | auburn
# Processing Record 45 of Set 8 | hofn
# Processing Record 46 of Set 8 | doha
# Processing Record 47 of Set 8 | young
# Processing Record 48 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 8 | muncar
# Processing Record 50 of Set 8 | taiyuan
# Processing Record 1 of Set 9 | leshukonskoye
# Processing Record 2 of Set 9 | gabu
# Processing Record 3 of Set 9 | lazaro cardenas
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | cusco
# Processing Record 6 of Set 9 | flinders
# Processing Record 7 of Set 9 | hami
# Processing Record 8 of Set 9 | severomorsk
# Processing Record 9 of Set 9 | grindavik
# Processing Record 10 of Set 9 | myitkyina
# Processing Record 11 of Set 9 | luganville
# Processing Record 12 of Set 9 | praya
# Processing Record 13 of Set 9 | urubicha
# Processing Record 14 of Set 9 | tambopata
# Processing Record 15 of Set 9 | yugorsk
# Processing Record 16 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 9 | ahipara
# Processing Record 18 of Set 9 | batouri
# Processing Record 19 of Set 9 | riyadh
# Processing Record 20 of Set 9 | shingu
# Processing Record 21 of Set 9 | chancay
# Processing Record 22 of Set 9 | odesskoye
# Processing Record 23 of Set 9 | phrai bung
# City not found. Skipping...
# Processing Record 24 of Set 9 | lokosovo
# Processing Record 25 of Set 9 | ricardo palma
# Processing Record 26 of Set 9 | los llanos de aridane
# Processing Record 27 of Set 9 | bengbu
# Processing Record 28 of Set 9 | vestmanna
# Processing Record 29 of Set 9 | verkhnevilyuysk
# Processing Record 30 of Set 9 | banda aceh
# Processing Record 31 of Set 9 | bandar-e lengeh
# Processing Record 32 of Set 9 | codrington
# Processing Record 33 of Set 9 | nangomba
# Processing Record 34 of Set 9 | sembakung
# Processing Record 35 of Set 9 | vadso
# Processing Record 36 of Set 9 | puerto escondido
# Processing Record 37 of Set 9 | manoel urbano
# Processing Record 38 of Set 9 | thinadhoo
# Processing Record 39 of Set 9 | maragogi
# Processing Record 40 of Set 9 | meulaboh
# Processing Record 41 of Set 9 | dunmore town
# Processing Record 42 of Set 9 | dzhebariki-khaya
# Processing Record 43 of Set 9 | porto belo
# Processing Record 44 of Set 9 | grand gaube
# Processing Record 45 of Set 9 | suntar
# Processing Record 46 of Set 9 | nanortalik
# Processing Record 47 of Set 9 | chimbote
# Processing Record 48 of Set 9 | neiafu
# Processing Record 49 of Set 9 | kharp
# Processing Record 50 of Set 9 | lata
# Processing Record 1 of Set 10 | chom bung
# City not found. Skipping...
# Processing Record 2 of Set 10 | tayshet
# Processing Record 3 of Set 10 | pyshma
# Processing Record 4 of Set 10 | fare
# Processing Record 5 of Set 10 | kununurra
# Processing Record 6 of Set 10 | matamoros
# Processing Record 7 of Set 10 | bairnsdale
# Processing Record 8 of Set 10 | bonfim
# Processing Record 9 of Set 10 | priekule
# Processing Record 10 of Set 10 | kalemie
# Processing Record 11 of Set 10 | saint anthony
# Processing Record 12 of Set 10 | pangnirtung
# Processing Record 13 of Set 10 | cowra
# Processing Record 14 of Set 10 | viransehir
# Processing Record 15 of Set 10 | namuac
# Processing Record 16 of Set 10 | sancti spiritus
# Processing Record 17 of Set 10 | hanko
# Processing Record 18 of Set 10 | nhulunbuy
# Processing Record 19 of Set 10 | amazar
# Processing Record 20 of Set 10 | kalaleh
# Processing Record 21 of Set 10 | naryan-mar
# Processing Record 22 of Set 10 | irbeyskoye
# Processing Record 23 of Set 10 | ganzhou
# Processing Record 24 of Set 10 | alibag
# Processing Record 25 of Set 10 | awjilah
# Processing Record 26 of Set 10 | lalin
# Processing Record 27 of Set 10 | moncada
# Processing Record 28 of Set 10 | sete
# Processing Record 29 of Set 10 | alofi
# Processing Record 30 of Set 10 | dukat
# Processing Record 31 of Set 10 | dunedin
# Processing Record 32 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 33 of Set 10 | port lincoln
# Processing Record 34 of Set 10 | san matias
# Processing Record 35 of Set 10 | marzuq
# Processing Record 36 of Set 10 | miri
# Processing Record 37 of Set 10 | murmashi
# Processing Record 38 of Set 10 | manicore
# Processing Record 39 of Set 10 | pingzhuang
# Processing Record 40 of Set 10 | panama city
# Processing Record 41 of Set 10 | beisfjord
# Processing Record 42 of Set 10 | lingyuan
# Processing Record 43 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 10 | lima
# Processing Record 45 of Set 10 | boulder city
# Processing Record 46 of Set 10 | sangmelima
# Processing Record 47 of Set 10 | nong bua
# Processing Record 48 of Set 10 | barra do bugres
# Processing Record 49 of Set 10 | roebourne
# Processing Record 50 of Set 10 | kamina
# Processing Record 1 of Set 11 | grand bank
# Processing Record 2 of Set 11 | vagay
# Processing Record 3 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 11 | bulungu
# Processing Record 5 of Set 11 | marawi
# Processing Record 6 of Set 11 | vardo
# Processing Record 7 of Set 11 | awbari
# Processing Record 8 of Set 11 | umm lajj
# Processing Record 9 of Set 11 | udachnyy
# Processing Record 10 of Set 11 | kracheh
# City not found. Skipping...
# Processing Record 11 of Set 11 | siilinjarvi
# Processing Record 12 of Set 11 | kahului
# Processing Record 13 of Set 11 | atar
# Processing Record 14 of Set 11 | batagay
# Processing Record 15 of Set 11 | itarare
# Processing Record 16 of Set 11 | skjervoy
# Processing Record 17 of Set 11 | kirakira
# Processing Record 18 of Set 11 | axim
# Processing Record 19 of Set 11 | pavilosta
# Processing Record 20 of Set 11 | reichenau
# Processing Record 21 of Set 11 | aleppo
# Processing Record 22 of Set 11 | muret
# Processing Record 23 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 24 of Set 11 | maun
# Processing Record 25 of Set 11 | shatin
# Processing Record 26 of Set 11 | qaqortoq
# Processing Record 27 of Set 11 | laredo
# Processing Record 28 of Set 11 | ciudad bolivar
# Processing Record 29 of Set 11 | maroua
# Processing Record 30 of Set 11 | razole
# Processing Record 31 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 32 of Set 11 | hambantota
# Processing Record 33 of Set 11 | sola
# Processing Record 34 of Set 11 | nipawin
# Processing Record 35 of Set 11 | santa lucia
# Processing Record 36 of Set 11 | poya
# Processing Record 37 of Set 11 | charkhari
# Processing Record 38 of Set 11 | nolinsk
# Processing Record 39 of Set 11 | balclutha
# Processing Record 40 of Set 11 | sistranda
# Processing Record 41 of Set 11 | phuket
# Processing Record 42 of Set 11 | camocim
# Processing Record 43 of Set 11 | mtsamboro
# Processing Record 44 of Set 11 | amalner
# Processing Record 45 of Set 11 | ahuimanu
# Processing Record 46 of Set 11 | miram shah
# Processing Record 47 of Set 11 | arlit
# Processing Record 48 of Set 11 | praia da vitoria
# Processing Record 49 of Set 11 | sioux lookout
# Processing Record 50 of Set 11 | hamilton
# Processing Record 1 of Set 12 | gorontalo
# Processing Record 2 of Set 12 | uglezavodsk
# Processing Record 3 of Set 12 | harrisburg
# Processing Record 4 of Set 12 | holme
# Processing Record 5 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 12 | fairbanks
# Processing Record 7 of Set 12 | sweetwater
# Processing Record 8 of Set 12 | khandyga
# Processing Record 9 of Set 12 | orlovskiy
# Processing Record 10 of Set 12 | mayo
# Processing Record 11 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 12 of Set 12 | severo-kurilsk
# Processing Record 13 of Set 12 | naples
# Processing Record 14 of Set 12 | shakawe
# Processing Record 15 of Set 12 | san policarpo
# Processing Record 16 of Set 12 | irbil
# Processing Record 17 of Set 12 | shaoxing
# Processing Record 18 of Set 12 | kaura namoda
# Processing Record 19 of Set 12 | rayong
# Processing Record 20 of Set 12 | morris
# Processing Record 21 of Set 12 | bollnas
# Processing Record 22 of Set 12 | ayan
# Processing Record 23 of Set 12 | odweyne
# Processing Record 24 of Set 12 | kuruman
# Processing Record 25 of Set 12 | itanhandu
# Processing Record 26 of Set 12 | tazovskiy
# Processing Record 27 of Set 12 | vytegra
# Processing Record 28 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 12 | teruel
# Processing Record 30 of Set 12 | shu
# Processing Record 31 of Set 12 | jiuquan
# Processing Record 32 of Set 12 | aquiraz
# Processing Record 33 of Set 12 | sibolga
# Processing Record 34 of Set 12 | elliot lake
# Processing Record 35 of Set 12 | bismil
# Processing Record 36 of Set 12 | draguignan
# Processing Record 37 of Set 12 | ukiah
# Processing Record 38 of Set 12 | kikwit
# Processing Record 39 of Set 12 | avera
# Processing Record 40 of Set 12 | bouloupari
# Processing Record 41 of Set 12 | baykit
# Processing Record 42 of Set 12 | ixtapa
# Processing Record 43 of Set 12 | saint-joseph
# Processing Record 44 of Set 12 | pincher creek
# Processing Record 45 of Set 12 | suluq
# Processing Record 46 of Set 12 | dwarka
# Processing Record 47 of Set 12 | rio grande
# Processing Record 48 of Set 12 | mouzakion
# City not found. Skipping...
# Processing Record 49 of Set 12 | padang
# Processing Record 50 of Set 12 | lusaka
# Processing Record 1 of Set 13 | adelaide
# Processing Record 2 of Set 13 | bac lieu
# Processing Record 3 of Set 13 | merauke
# Processing Record 4 of Set 13 | banjar
# Processing Record 5 of Set 13 | muros
# Processing Record 6 of Set 13 | port hedland
# Processing Record 7 of Set 13 | novozavidovskiy
# Processing Record 8 of Set 13 | san andres
# Processing Record 9 of Set 13 | vanimo
# Processing Record 10 of Set 13 | ongole
# Processing Record 11 of Set 13 | kashi
# Processing Record 12 of Set 13 | matara
# Processing Record 13 of Set 13 | cartagena
# Processing Record 14 of Set 13 | tuskegee
# Processing Record 15 of Set 13 | cayenne
# Processing Record 16 of Set 13 | ankang
# Processing Record 17 of Set 13 | cherskiy
# Processing Record 18 of Set 13 | lara
# Processing Record 19 of Set 13 | barra patuca
# Processing Record 20 of Set 13 | asau
# Processing Record 21 of Set 13 | biak
# Processing Record 22 of Set 13 | skibotn
# Processing Record 23 of Set 13 | margate
# Processing Record 24 of Set 13 | nelson bay
# Processing Record 25 of Set 13 | ancud
# Processing Record 26 of Set 13 | port hueneme
# Processing Record 27 of Set 13 | ous
# Processing Record 28 of Set 13 | la cruz
# Processing Record 29 of Set 13 | zambezi
# Processing Record 30 of Set 13 | nuevitas
# Processing Record 31 of Set 13 | gberia fotombu
# Processing Record 32 of Set 13 | mitsamiouli
# Processing Record 33 of Set 13 | nemuro
# Processing Record 34 of Set 13 | santa maria
# Processing Record 35 of Set 13 | ngorongoro
# Processing Record 36 of Set 13 | kathu
# Processing Record 37 of Set 13 | mumford
# Processing Record 38 of Set 13 | kipini
# Processing Record 39 of Set 13 | rocha
# Processing Record 40 of Set 13 | kaili
# Processing Record 41 of Set 13 | altus
# Processing Record 42 of Set 13 | chaozhou
# Processing Record 43 of Set 13 | victor harbor
# Processing Record 44 of Set 13 | jacareacanga
# Processing Record 45 of Set 13 | sakakah
# Processing Record 46 of Set 13 | zeya
# Processing Record 47 of Set 13 | aitape
# Processing Record 48 of Set 13 | kiama
# Processing Record 49 of Set 13 | khani
# Processing Record 50 of Set 13 | ust-nera
# Processing Record 1 of Set 14 | san pedro
# Processing Record 2 of Set 14 | camiri
# Processing Record 3 of Set 14 | marsh harbour
# Processing Record 4 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 5 of Set 14 | orange cove
# Processing Record 6 of Set 14 | tenosique
# Processing Record 7 of Set 14 | kemi
# Processing Record 8 of Set 14 | cordoba
# Processing Record 9 of Set 14 | satis
# Processing Record 10 of Set 14 | fujin
# Processing Record 11 of Set 14 | alzamay
# Processing Record 12 of Set 14 | mao
# Processing Record 13 of Set 14 | brokopondo
# Processing Record 14 of Set 14 | kayes
# Processing Record 15 of Set 14 | la paz
# Processing Record 16 of Set 14 | cabedelo
# Processing Record 17 of Set 14 | khilok
# Processing Record 18 of Set 14 | grand-santi
# Processing Record 19 of Set 14 | nakusp
# Processing Record 20 of Set 14 | krasnoselkup
# Processing Record 21 of Set 14 | miandrivazo
# Processing Record 22 of Set 14 | staicele
# Processing Record 23 of Set 14 | koungheul
# Processing Record 24 of Set 14 | vila franca do campo
# Processing Record 25 of Set 14 | nyurba
# Processing Record 26 of Set 14 | srednekolymsk
# Processing Record 27 of Set 14 | chadan
# Processing Record 28 of Set 14 | rio brilhante
# Processing Record 29 of Set 14 | rumoi
# Processing Record 30 of Set 14 | oga
# Processing Record 31 of Set 14 | bontang
# Processing Record 32 of Set 14 | rincon
# Processing Record 33 of Set 14 | severo-yeniseyskiy
# Processing Record 34 of Set 14 | jingdezhen
# Processing Record 35 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 14 | santa cruz del norte
# Processing Record 37 of Set 14 | totana
# Processing Record 38 of Set 14 | bonavista
# Processing Record 39 of Set 14 | qui nhon
# Processing Record 40 of Set 14 | henties bay
# Processing Record 41 of Set 14 | san jose
# Processing Record 42 of Set 14 | batagay-alyta
# Processing Record 43 of Set 14 | putina
# Processing Record 44 of Set 14 | tchibanga
# Processing Record 45 of Set 14 | mantua
# Processing Record 46 of Set 14 | mnogovershinnyy
# Processing Record 47 of Set 14 | rodez
# Processing Record 48 of Set 14 | severodvinsk
# Processing Record 49 of Set 14 | yumen
# Processing Record 50 of Set 14 | salinas
# Processing Record 1 of Set 15 | topola
# Processing Record 2 of Set 15 | kuki
# Processing Record 3 of Set 15 | agadir
# Processing Record 4 of Set 15 | batemans bay
# Processing Record 5 of Set 15 | sorong
# Processing Record 6 of Set 15 | oussouye
# Processing Record 7 of Set 15 | malabo
# Processing Record 8 of Set 15 | todos santos
# Processing Record 9 of Set 15 | jining
# Processing Record 10 of Set 15 | ust-kuyga
# Processing Record 11 of Set 15 | tahta
# Processing Record 12 of Set 15 | bagdarin
# Processing Record 13 of Set 15 | taksimo
# Processing Record 14 of Set 15 | nizhneangarsk
# Processing Record 15 of Set 15 | solnechnyy
# Processing Record 16 of Set 15 | nampula
# Processing Record 17 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 18 of Set 15 | college
# Processing Record 19 of Set 15 | mende
# Processing Record 20 of Set 15 | kunming
# Processing Record 21 of Set 15 | shunyi
# Processing Record 22 of Set 15 | sidi ali
# Processing Record 23 of Set 15 | pozo colorado
# Processing Record 24 of Set 15 | cuyo
# Processing Record 25 of Set 15 | smithers
# Processing Record 26 of Set 15 | mana
# Processing Record 27 of Set 15 | yei
# Processing Record 28 of Set 15 | katangli
# Processing Record 29 of Set 15 | natal
# Processing Record 30 of Set 15 | kamyshevatskaya
# Processing Record 31 of Set 15 | ilek
# Processing Record 32 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 15 | talara
# Processing Record 34 of Set 15 | abaza
# Processing Record 35 of Set 15 | la ronge
# Processing Record 36 of Set 15 | moskovskiy
# Processing Record 37 of Set 15 | jiaojiang
# Processing Record 38 of Set 15 | kampot
# Processing Record 39 of Set 15 | darnah
# Processing Record 40 of Set 15 | saluzzo
# Processing Record 41 of Set 15 | saint-leu
# Processing Record 42 of Set 15 | skelleftea
# Processing Record 43 of Set 15 | olga
# Processing Record 44 of Set 15 | san cristobal
# Processing Record 45 of Set 15 | shetpe
# Processing Record 46 of Set 15 | soto la marina
# Processing Record 47 of Set 15 | hammerfest
# Processing Record 48 of Set 15 | farsund
# Processing Record 49 of Set 15 | puerto del rosario
# Processing Record 50 of Set 15 | bumba
# Processing Record 1 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 16 | ambon
# Processing Record 3 of Set 16 | ponta delgada
# Processing Record 4 of Set 16 | tornio
# Processing Record 5 of Set 16 | raudeberg
# Processing Record 6 of Set 16 | troitsko-pechorsk
# Processing Record 7 of Set 16 | matay
# Processing Record 8 of Set 16 | saint-georges
# Processing Record 9 of Set 16 | pinsk
# Processing Record 10 of Set 16 | dalbandin
# Processing Record 11 of Set 16 | yelizovo
# Processing Record 12 of Set 16 | coahuayana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.74  -90.35     70.00        91          81
# 1         Bluff      NZ -46.60  168.33     55.00        64          85
# 2        Yulara      AU -25.24  130.99     86.00        13          23
# 3      Thompson      CA  55.74  -97.86     23.00        92          75
# 4     Tuatapere      NZ -46.13  167.68     55.00        64          47
# 5      Khatanga      RU  71.97  102.50      5.16        95          98
# 6       Okhotsk      RU  59.38  143.30     20.35        87         100
# 7      Lorengau      PG  -2.02  147.27     86.77        65          20
# 8       Rikitea      PF -23.12 -134.97     74.37        85          88
# 9       Kambove      CD -10.88   26.60     64.06        53           4
#
#    Wind Speed Weather Description
# 0        3.00       broken clouds
# 1       14.00     overcast clouds
# 2       11.41          few clouds
# 3        6.93       broken clouds
# 4       14.00    scattered clouds
# 5        5.91     overcast clouds
# 6       18.28     overcast clouds
# 7        5.28          few clouds
# 8       23.13          light rain
# 9        3.71           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
